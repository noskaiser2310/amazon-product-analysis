# %%
# backend/test_data_mapper.py
from data_mapper import ProductDataMapper

mapper = ProductDataMapper('../data/processed/amazon.csv')
products = mapper.get_all_products()

print(f"Total products: {len(products)}")
print(f"First product: {products[0]}")
print(f"Categories: {mapper.get_unique_categories()}")
# Out:
# Total products: 1351
# ...
